# %% [markdown]
# <a href="https://colab.research.google.com/github/haydenkirkeide/CAP-5771-Assignment-2-Files/blob/main/run1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
import numpy as np
from sklearn.svm import SVC

import warnings
warnings.filterwarnings('ignore')

# load data
X_train = np.loadtxt('X_train.txt')
y_train = np.loadtxt('y_train.txt')
X_test = np.loadtxt('X_test.txt').T
y_test = np.loadtxt('y_test.txt')

num_classes = y_train.shape[1]
num_test = X_test.shape[0]

print("Accuracy of Polynomial and Gaussian Kernels: \n--------------------------------------------")

# polynomial kernel setup
poly_pred = np.zeros((num_test, num_classes))
for class_idx in range(num_classes):
    y_class = y_train[:, class_idx].astype(int)
    svc = SVC(kernel='poly', degree=2, coef0=1, gamma='scale')
    svc.fit(X_train, y_class)
    pred = svc.predict(X_test)
    poly_pred[:, class_idx] = pred

# calculating accuracy for polynomial kernel
accs = []
for i in range(num_test):
    true_labels = y_test[i]
    pred_labels = poly_pred[i]
    intersection = np.sum(np.logical_and(true_labels == 1, pred_labels == 1))
    union = np.sum(np.logical_or(true_labels == 1, pred_labels == 1))
    if union == 0:
        acc = 1.0 if intersection == 0 else 0.0
    else:
        acc = intersection / union
    accs.append(acc)
poly_acc = np.mean(accs)

# print result of polynomial kernel
print(f"Polynomial Kernel: {poly_acc * 100:.2f}%")

# gaussian (AKA radial basis function AKA RBF) kernel setup
rbf_pred = np.zeros((num_test, num_classes))
for class_idx in range(num_classes):
    y_class = y_train[:, class_idx].astype(int)
    svc = SVC(kernel='rbf', gamma='scale')
    svc.fit(X_train, y_class)
    pred = svc.predict(X_test)
    rbf_pred[:, class_idx] = pred

# calculating accuracy for gaussian kernel
accs = []
for i in range(num_test):
    true_labels = y_test[i]
    pred_labels = rbf_pred[i]
    intersection = np.sum(np.logical_and(true_labels == 1, pred_labels == 1))
    union = np.sum(np.logical_or(true_labels == 1, pred_labels == 1))
    if union == 0:
        acc = 1.0 if intersection == 0 else 0.0
    else:
        acc = intersection / union
    accs.append(acc)
rbf_acc = np.mean(accs)

# print result of gaussian kernel
print(f"Gaussian Kernel: {rbf_acc * 100:.2f}%")
# Out:
# Accuracy of Polynomial and Gaussian Kernels:
# --------------------------------------------
# Polynomial Kernel: 62.33%
# Gaussian Kernel: 63.43%
